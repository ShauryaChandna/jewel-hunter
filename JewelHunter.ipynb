# %%
#MAIN CODE
import time
import sys

print('''     ██╗███████╗██╗    ██╗███████╗██╗        _________              
     ██║██╔════╝██║    ██║██╔════╝██║       /_|_____|_\     
     ██║█████╗  ██║ █╗ ██║█████╗  ██║       '. \   / .'    
██   ██║██╔══╝  ██║███╗██║██╔══╝  ██║         '.\ /.'  
╚█████╔╝███████╗╚███╔███╔╝███████╗███████╗      '.' 
 ╚════╝ ╚══════╝ ╚══╝╚══╝ ╚══════╝╚══════╝          
                                                       
██╗  ██╗██╗   ██╗███╗   ██╗████████╗███████╗██████╗ 
██║  ██║██║   ██║████╗  ██║╚══██╔══╝██╔════╝██╔══██╗
███████║██║   ██║██╔██╗ ██║   ██║   █████╗  ██████╔╝
██╔══██║██║   ██║██║╚██╗██║   ██║   ██╔══╝  ██╔══██╗
██║  ██║╚██████╔╝██║ ╚████║   ██║   ███████╗██║  ██║
╚═╝  ╚═╝ ╚═════╝ ╚═╝  ╚═══╝   ╚═╝   ╚══════╝╚═╝  ╚═╝
                                                         ''')

print(),print('-----'*20),print(),print()
username=input("Enter your name: ")
print()
a=input('Press Enter to start game')
print()
print('-----'*20)
print()
health=10
bag=['Rope', 'Shovel','Phone Charger','Torch','Wire Cutters','Extra Clothes','Axe','Food','Sunglasses','Map' ,'Lighter']
def BagStatus():
  print('Inventory ----> ', end='')
  for i in bag:
    print(i, end='   ')
  print()
  print()
def HealthStatus():
  global health
  if health <= 0:
    health = 0
  print('Health ----->'+'['+ health*'|'+ (10-health)*'-'+ ']')
  if health == 0:
    print('GAME OVER')
    sys.exit()
  print()
def CheckMainInput():
  global MAININPUT
  if MAININPUT == 'bag':
    BagStatus()
  elif MAININPUT == 'health':
    HealthStatus()

def wall():
  global health
  print('''
                                 {} {}
                         !  !  ! II II !  !  !
                      !  I__I__I_II II_I__I__I  !
                      I_/|__|__|_|| ||_|__|__|\_I
                   ! /|_/|  |  | || || |  |  |\_|\ !       
       .--.        I//|  |  |  | || || |  |  |  |\\I        .--.
      /-   \    ! /|/ |  |  |  | || || |  |  |  | \|\ !    /=   \.
      \=__ /    I//|  |  |  |  | || || |  |  |  |  |\\I    \-__ /
       }  {  ! /|/ |  |  |  |  | || || |  |  |  |  | \|\ !  }  {
      {____} I//|  |  |  |  |  | || || |  |  |  |  |  |\\I {____}
_!__!__|= |=/|/ |  |  |  |  |  | || || |  |  |  |  |  | \|\=|  |__!__!_
_I__I__|  ||/|__|__|__|__|__|__|_|| ||_|__|__|__|__|__|__|\||- |__I__I_
-|--|--|- ||-|--|--|--|--|--|--|-|| ||-|--|--|--|--|--|--|-||= |--|--|-
 |  |  |  || |  |  |  |  |  |  | || || |  |  |  |  |  |  | ||  |  |  |
 |  |  |= || |  |  |  |  |  |  | || || |  |  |  |  |  |  | ||= |  |  |
 |  |  |- || |  |  |  |  |  |  | || || |  |  |  |  |  |  | ||= |  |  |
 |  |  |- || |  |  |  |  |  |  | || || |  |  |  |  |  |  | ||- |  |  | 
_|__|__|  ||_|__|__|__|__|__|__|_|| ||_|__|__|__|__|__|__|_||  |__|__|_
-|--|--|= ||-|--|--|--|--|--|--|-|| ||-|--|--|--|--|--|--|-||- |--|--|-
-|--|--|| |  |  |  |  |  |  | || || |  |  |  |  |  |  | ||= |  |  | 
~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^~~~~~~~~~~~''')
  print('You have reached the 20-feet high gate covered with cobwebs.')
  print('Try to use something from your bag...')
  print()
  MAININPUT = input('Use the function to open your bag: ')
  CheckMainInput()
  print()
  print('(1) Climb over the gate with a rope    (2) Dig a tunnel under the gate using the shovel')
  Choice = int(input('Enter 1 or 2: '))
  if Choice == 1:
    if 'Rope' in bag and 'Shovel' in bag:
      print('Oh no! Hundreds of tiny spiders bite your hand!')
      print('Your health has reduced by 2 bars!')
      print('Your only option is to dig a tunnel with the shovel')
      health-=2
      bag.remove('Rope')
      bag.remove('Shovel')
      BagStatus()
      
    elif 'Rope' not in bag:
      print('You do not have a Rope anymore, so you use the shovel')
      print('You avoided the spiders that had made the cobwebs and made it through the gate!')
      bag.remove('Shovel')
      BagStatus()
     
    elif 'Shovel' not in bag:
      print('Oh no! Hundreds of tiny spiders bite your hand!\n\
      Your health has reduced by 2 bars!')
      print('As you do not have a shovel, you cannot dig your way through.')
      print('You are stuck! Please restart the game :(')
      health=0

  elif Choice == 2:
    if 'Shovel' in bag:
      print('Well done! You avoided the spiders that had made the cobwebs and made it through the gate!')
      bag.remove('Shovel')
      BagStatus()
      
    elif 'Shovel' not in bag:
      print('You already used your shovel, so you try to use the rope')
      print('Oh no! Hundreds of tiny spiders bite your hand!\nYour \
      health has reduced by 2 bars!')
      print('With no options left, your game has ended! Please restart the game :(')
      health=0
  HealthStatus()
  blank = input('Press Enter to continue')
  print() 
  print('-----'*20)
  print() 
  spider()
    
def puzzle():
  print('You walk toward the door, but there is a lock on it which requires a 4-digit code')
  print(username+': "Maybe there is something under the doormat. Here it is. The clue for the lock"')
  print('''        -----------------------------
        |     Monday = 617           |
        |     Tuesday = 729          |
        |     Wednesday = 9312       |
        |     Thursday = 8412        |
        |     Friday = 6511          |
        |     Saturday = 8614        |
        |     Sunday = ????          |
        ------------------------------''')
  answer = int(input('Enter the 4-digit code: '))
  count=0
  while True:
    if answer == 6713:
      print('You cracked the code! ')
      blank = input('Press Enter to continue')
      darkness()
    else:
      count+=1
      if count==3:
        print('HINT: The first digit depends on the length of the word ')
        print('      The second digit depends on the day of the week ')
      else:
        print('Try again')
        answer = int(input('Enter the 4-digit code: '))


def spider():
  print('''           ____                      ,
          /---..__              ____//
               '--.\           / ---'
          _______  \\         //
        / ------ \  \|       '/  ______
       //  ___  \ \ ||/ \  //  _/_---- \__
      |/  /.-.\  \ \:|< >|:// _/.'..\   '--'
         //   \'. | \'.|.'/ /_/ /  \\
        //     \ \_\/" ' "\-'.-'    \\
       //       '-._| :O: |'-.__     \\
      //           (/'==='\)'-._\     ||
      ||                        \\    \|
      ||                         \\    '
      |/                          \\
                                   ||
                                   ||
                                   \\
                                    ''')
  global health
  count=0
  print('As soon as you stand up, a giant spider bites your back!')
  print('Turn your caps lock off')
  a=input('Press Enter to continue')
  print('A Giant Spider is about to attack you, BE READY!')
  start = time.time()
  dodge1 = input('Enter w to dodge!')
  dodge2 = input('Enter 2 to dodge!')
  dodge3 = input('Enter z to dodge!')
  stop = time.time()
  v= stop - start
  if v>7:
    print("Too Slow")
    health-=4
    print('You have lost health by 4 bars')
  elif v<7:
    if dodge1!='w':
      count+=1
    if dodge2!= '2':
      count+=1
    if dodge3!='z':
      count+=1
    print('You dodged ' + str(3-count) + ' attacks and lost '+str(count*2)+' bars of health')
    print()
  health-=count*2
  HealthStatus()
  print('Now get READY TO ATTACK WITH YOUR SWORD!')
  blank=input('Press Enter to continue: ')
  start = time.time()
  attack=input('Enter 15628 to attack: ')
  stop=time.time()
  v=stop-start
  if v>5:
    print('You took too much time, the spider attacked you first')
    print('You have lost 4 bars of health')
    health-=4
  elif v<6:
    if attack == '15628':
      print('*SWOOSH*  You have killed the spider with your sword')
    else:
      print('You entered the wrong number, you stumble and the spider bites you')
      print('You have lost 4 bars of health')
      health-=4
  HealthStatus()
  blank=input('Press Enter to continue')
  print() 
  print('-----'*20)
  print()
  if 'Healing Potion' in bag:
    print('Do you want to recover using the healing potion?: ')
    choice = input('Enter yes or no: ')
    if choice == 'yes':
      health+=5
      if health>10:
        health=10
      HealthStatus()
      bag.remove('Healing Potion')
    elif choice =='no':
      print('Alright, remember its still in your bag so you can use it later.')
  if 'Herbs' in bag:
    print('Unfortunately the herbs were crushed while digging the tunnel.')
    print('The Herbs have been destroyed.')
  blank = input('Press Enter to continue: ')
  print() 
  print('-----'*20)
  print()
  puzzle()

def heal():
  global health
  print() 
  print('-----'*20)
  print()
  print('Do you want to recover using the healing potion?: ')
  choice = input('Enter yes or no: ')
  if choice == 'yes':
    health+=5
    bag.remove('Healing Potion')
    if health>10:
      health=10
    HealthStatus()
  elif choice =='no':
    print('Alright, remember its still in your bag so you can use it later.')   
  blank = input('Press Enter to continue: ')
  cave()

def darkness():
  global health
  print()
  print('-----'*20)
  print()
  print('*CREAK* The door opens and you enter the room.')
  print('It is dark and you need to be aware of your surroundings')
  print('Open your bag to use an item: ')
  print()
  MAININPUT = input('Enter "bag": ')
  CheckMainInput()
  print('Remember some items have more than 1 purpose which you might need later')
  item = input('Which item do you want to use?: ')
  print()
  while True:
    if item.title() == 'Torch' or item.title() =='Lighter':
      print('You have decided to use the '+item.title())
      bag.remove(item.title())
      BagStatus()
      break
    else:
      print('How can you use',item.title(),'for light? Please Try Again')
      item = input('Which item do you want to use?: ')
  print('You see a table in front of you and you walk towards it')
  print()
  print('''    _______
   |.-----.|
   |```````|
   \       /
    `-. .-'          
       |    
     __|__  
    `-----` ''')
  print(username,': "WOW! That blue, shiny drink might give me powers.')
  print('       But is it a risk Im willing to take?')
  yn=input('yes or no: ')
  if yn =='yes':
    print('You drink the blue shiny liquid and start to feel something changing')
    print(username, ': YES! Im getting powers!')
    print('Nope, that was snake venom and you just fainted')
    print('You have lost 4 bars of health')
    health-=4
    HealthStatus()
    print('Goblin Guards find you and take you to a cave in the castle.')
  elif yn == 'no':
    print('Smart move, be cautious and be sure of what youre doing.')
    print('Unfortunately, the Goblins have taken you prisoner and have taken you to a cave in the castle.')
  blank = input('Press Enter to continue: ')
  if 'Healing Potion' in bag:
    heal()
  else:
    cave()

def cave():
  global health
  print()
  print('-----'*20)
  print()
  print('In the Cave...')
  print('As you open your eyes, you see a huge red Dragon around the Jewel of Walaba!')
  print('You jump at it with your sword, but the dragon seems unaffected.')
  print('The dragon opens it mouth and is about to spread fire all over you...')
  time.sleep(3)
  print()
  print('Suddenly a light appears and shines into your eyes')
  print('(1) Use the magnifying lens to concentrate the light at the dragon')
  print('    and burn the dragon ')
  print('(2) Use the sunglasses to protect your eyes and')
  print('    see clearly')
  choice = int(input('Choose 1 or 2: '))
  if choice == 1:
    print('As the magnifying lens is small, it concentrates a small amount of light')
    print('It hardly damages the Dragon')
    print('The Dragon swings his tail at you and your health decreases by 4 bars')
    health-=4
    HealthStatus()
  elif choice == 2:
    print('Good thinking, you cant defend yourself without seeing')
    bag.remove('Sunglasses')
  print(username,': "Oh! I almost forgot about the clue that the old man gave me!"')
  print(username,': "If only I could recall what the clue was..."(SCROLL UP)')
  MAININPUT = input('Enter "bag" to use an item to defeat the dragon: ')
  CheckMainInput()
  weapon = input('Choose your weapon: ')
  if weapon.title() == 'Lighter':
    print('The dragons weakness was also its strength!')
    print('The Dragon has been defeated')
    print('You have captured the JEWEL OF WALABA')
    print(""" 
    _________
   /_|_____|_\ 
   '. \   / .'
     '.\ /.'
       '.'""")
    win()
  else: 
    if weapon.title() in bag:
      print('The dragon could not be defeated with the',weapon.title())
    else:
      print('You dont have this weapon')
    print('The dragon breathes fire at you and you die.')
    health = 0
    HealthStatus()

def win():
  
  print()
  print('-----'*20)
  print()
  print('(THE NEXT DAY)')
  time.sleep(2)
  print(username,': "Thank you for the clue, I wouldnt have been able to do it without you"')
  time.sleep(2)
  print('Old Man: "Id like to thank you too."')
  time.sleep(2)
  print(username,': "For what? The',rem.title()+'?"')
  time.sleep(2)
  print('Old Man: "No.', end=' ')
  time.sleep(2)
  print('Thanks for the JEWEL"')
  time.sleep(3)
  print()
  print('The Old Man snatches the Jewel of Walaba from your hands')
  time.sleep(2)
  print('*BOOM*')
  time.sleep(2)
  print('Before you can react, he punches you and runs away')
  time.sleep(1)
  print('CATCH THE THIEF IN THE SEQUEL')
  time.sleep(3)
  print()
  print('''     ██╗███████╗██╗    ██╗███████╗██╗     
     ██║██╔════╝██║    ██║██╔════╝██║     
     ██║█████╗  ██║ █╗ ██║█████╗  ██║     
██   ██║██╔══╝  ██║███╗██║██╔══╝  ██║     
╚█████╔╝███████╗╚███╔███╔╝███████╗███████╗
 ╚════╝ ╚══════╝ ╚══╝╚══╝ ╚══════╝╚══════╝
                                          
████████╗██╗  ██╗██╗███████╗███████╗    ███
╚══██╔══╝██║  ██║██║██╔════╝██╔════╝    ███
   ██║   ███████║██║█████╗  █████╗      ███
   ██║   ██╔══██║██║██╔══╝  ██╔══╝      ███
   ██║   ██║  ██║██║███████╗██║          
   ╚═╝   ╚═╝  ╚═╝╚═╝╚══════╝╚═╝         ███
                                          ''')
  sys.exit()
  
def gun():
  print()
  global health
  print('-----'*20)
  print()
  print('''                                  |>>>
                                  |
                    |>>>      _  _|_  _         |>>>
                    |        |;| |;| |;|        |
                _  _|_  _    \\.    .  /    _  _|_  _
               |;|_|;|_|;|    \\:. ,  /    |;|_|;|_|;|
               \\..      /    ||;   . |    \\.    .  /
                \\.  ,  /     ||:  .  |     \\:  .  /
                 ||:   |_   _ ||_ . _ | _   _||:   |
                 ||:  .|||_|;|_|;|_|;|_|;|_|;||:.  |
                 ||:   ||.    .     .      . ||:  .|
                 ||: . || .     . .   .  ,   ||:   |       \,/
                 ||:   ||:  ,  _______   .   ||: , |    /^\      \,/
                 ||:   || .   /+++++++\    . ||:   |
                 ||:   ||.    |+++++++| .    ||: . |
              __ ||: . ||: ,  |+++++++|.  . _||_   |
     ____--`~    '--~~__|.    |+++++++|----~    ~`---,              ___
-~--~                   ~---__|+++++++|               ~~----_____-~'   `~----~~''')
  print(),print()
  print('The castle comes into view. It is surrounded by goblin guards in towers')
  if 'Gun' not in bag:
    print(username,''": Oh no! If only I had a gun. I dont have any option but to make a run for it") 
    print('While running into the castle, you get shot by a guard and lose 3 bars of health') 
    health-=3
    HealthStatus()
    print('The guard is about to sound the alarm! Use something from your bag ')
    print('to disable the alarm system')
  elif 'Gun' in bag:
    count=0
    print(username,''": Thank God I have a gun! I can shoot down these goblins now!")
    print('GOBLIN 1:') 
    print()
    print('''            
                             ( )
                              0                    
                             /||\                    
                            / /\ \                   
                             /  \ _____
                            |    
                            |    
           ____             | 5m 
      0____|+               |    
    /||                     |
   / /\                     |              
    /  \ ___________________|         
                5m''')
    print()
    ang=int(input('With what angle(degree) should you should tilt your gun upwards?: '))
    print()
    print('GOBLIN 2:') 
    print()
    print('''            
                             ( )
                              0                    
                             /||\                    
                            / /\ \                   
                             /  \ _____
                            |    
                            |
                            |
                            |
                            |    
           ____             | 5√3 m
      0____|+               |    
    /||                     |
   / /\                     |              
    /  \ ___________________|         
                5m''')
    print()
    ang2=int(input('With what angle(degree) should you should tilt your gun upwards?: '))
    if ang == 45:
      count+=1
    if ang2 == 60:
      count+=1
    print('You shot',count,'Goblin Guard(s) and lost',(2-count)*2,'bars of health')
    health-=(2-count)*2
    HealthStatus()
    print()
    blank = input('Press Enter to continue: ')
    print()
    print('Use something from your bag to disable the security system.')
    bag.remove('Gun')
  MAININPUT = input('Use the function to open your bag: ')
  CheckMainInput()
  tool = input('Select your tool: ')
  while True:
    if tool.title() == 'Wire Cutters':
      print('Great job! Now make your way towards the wall in front of you')
      bag.remove(tool.title())
      break
    else:
      print('Wrong tool! What would help you disable a security system?: ')
      tool = input('Select your tool: ')
  blank = input('Press Enter to continue: ')
  print()
  print('-----'*20)
  print()
  wall()


print('You have finally reached the forest, in search of the Jewel of Walaba,\nYou \
look around and see nothing but dark gloomy trees for \
miles and miles.\nThe only thing you have is your bag. \nOpen your bag to check your inventory\nYour \
inventory may or may not help you...')
print()
instructions = 'Functions:\n   Input\n1) bag ----> to see your inventory\n2) health ----> to check your health\n\nYou \
can use these functions at any point in the adventure\nREMEMBER THAT ALL THE INPUTS ARE CASE-SENITIVE SO \
MAKE SURE YOU WRITE "Abc" AS "Abc" AND NOT "abc"'

print(instructions)
print('You also have a sword with you')
print()
MAININPUT=input('Enter bag or health to check them: ')
if MAININPUT =='health':
  print('Full bar of health -----> [||||||||||]')
  print('Half bar of health -----> [|||||-----]')
CheckMainInput()
MAININPUT=input('Enter bag or health to check them: ')
if MAININPUT =='health':
  print('Full bar of health -----> [||||||||||]')
  print('Half bar of health -----> [|||||-----]')
CheckMainInput()
blank=input('Press Enter to continue...')
print() 

health = 10
print('-----'*20)
print()
print('While walking you find a Phone and a Gun, but you only have space for 1 item in your inventory\nWhat \
will you pick?\nChoose carefully...\n(1) Phone    (2) Gun')
choice=int(input('Enter 1 or 2: '))
if choice == 1:
  print('Bad choice. With no service in the forest you cannot contact anyone for help')
  bag.append('Phone')
elif choice == 2:
  print('Good choice, the gun may help you later')
  bag.append('Gun')
BagStatus()
blank=input('Press Enter to continue...')
print() 
print('-----'*20)
print()
print('Old Man: "Hey, listen up! Dont go that way! That Castle is haunted!"')
time.sleep(1)
print(username,':"Good evening sir, I am in search of the Jewel of Walaba. Please help me find it."')
time.sleep(1)
print('Old Man: "There is a Humongous Dragon in the Castle. I hope you are strong enough to fight it."' )
time.sleep(1)
print(username,':"I have been preparing all my life for this moment. Tell me, how do I beat this dragon?"')
time.sleep(1)
print('Old Man: "I have a clue with me, but I need something in return."' )
print()
MAININPUT=input('Enter "bag" to check your inventory: ')
CheckMainInput()
rem=input('What do you want to exchange the clue for?: ')
bag.remove(rem.title())
BagStatus()
print()
print('Old Man: "Thank you for the '+rem.title()+'. Here is the clue: "' )
print('''        -----------------------------
        |     "I am not alive,       |
        |     but I grow             |
        |     I don't have lungs     |                               
        |     but I need air"        |
        ------------------------------''')
print(username+':"Thank you so much. I am pretty sure it will help me later. Goodbye."')
blank=input('Press Enter to continue...')
print() 
print('-----'*20)
print()
print(username+': "Hey! Those are medicinal herbs. Should I make the healing potion right now or save it for later?"\n\
 (1) Make the healing potion     (2) Save herbs for later')
choice = int(input('Enter 1 or 2: '))
if choice == 1:
  bag.append('Healing Potion')
else:
  bag.append('Herbs')
BagStatus()
blank = input('Press Enter to continue: ')
print()
print('-----'*20)
print()
gun()
# Out:
#      ██╗███████╗██╗    ██╗███████╗██╗        _________
#      ██║██╔════╝██║    ██║██╔════╝██║       /_|_____|_\
#      ██║█████╗  ██║ █╗ ██║█████╗  ██║       '. \   / .'
# ██   ██║██╔══╝  ██║███╗██║██╔══╝  ██║         '.\ /.'
# ╚█████╔╝███████╗╚███╔███╔╝███████╗███████╗      '.'
#  ╚════╝ ╚══════╝ ╚══╝╚══╝ ╚══════╝╚══════╝
#
# ██╗  ██╗██╗   ██╗███╗   ██╗████████╗███████╗██████╗
# ██║  ██║██║   ██║████╗  ██║╚══██╔══╝██╔════╝██╔══██╗
# ███████║██║   ██║██╔██╗ ██║   ██║   █████╗  ██████╔╝
# ██╔══██║██║   ██║██║╚██╗██║   ██║   ██╔══╝  ██╔══██╗
# ██║  ██║╚██████╔╝██║ ╚████║   ██║   ███████╗██║  ██║
# ╚═╝  ╚═╝ ╚═════╝ ╚═╝  ╚═══╝   ╚═╝   ╚══════╝╚═╝  ╚═╝
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Enter your name: s
#
# Press Enter to start game
#
# ----------------------------------------------------------------------------------------------------
#
# ...
